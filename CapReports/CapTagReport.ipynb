# %% [markdown]
# # 1. Run Single Cap Tag Report

# %% [markdown]
# Run a cap tag report (same output as in Excel).
#
# **Inputs**
# 1. PR number and revision in form: PR_rev, i.e. '1-IWH6ME_2'
# 2. Directory to write cap tag report .csv file to, i.e. 'C:\\Users\\wb5888\\Documents\\Cap Tags'
#
# **Outputs**
# 1. On-screen cap tag report
# 2. Report exported as .csv file with name CP_PR_rev.csv, i.e. '1-IWH6ME_2.csv' to directory provided above

# %% [markdown]
# ### Input PR_rev and directory

# %%
import os
import numpy as np
import pandas as pd
import CapTags as ct

pr_rev = '1-J10Y50_1'

#1-J10Y50_1
write_dir = 'C:\\Users\\wb5888\\Documents\\Cap Tags'

# %% [markdown]
# ### View Report

# %% [markdown]
# View report that will be exported.

# %%
report = ct.get_report(pr_rev)
report
# Out:
#          CustomerName CustomerID           LDC_Account  \
# 0   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 1   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 2   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 3   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 4   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 5   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 6   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 7   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 8   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 9   MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
# 10  MAXION IMPORT LLC   1-7A2L9R  08019108110001554695
#
#                           AccountID  UIDaccount MarketCode ContractID  \
# 0   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 1   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 2   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 3   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 4   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 5   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 6   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 7   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 8   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 9   PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
# 10  PJM_ATSIOE_08019108110001554695      752769        PJM   1-J10Y50
#
#     Revision  StartTime            StopTime                TagType        Tag  \
# 0          1 2016-06-01 2017-05-31 23:59:59      CAPACITY_TAG_OVRD  2256.3815
# 1          1 2017-06-01 2018-05-31 23:59:59      CAPACITY_TAG_OVRD  1999.7090
# 2          1 2018-06-01 2019-05-31 23:59:59      CAPACITY_TAG_OVRD  2385.4158
# 3          1 2019-06-01 2020-05-31 23:59:59      CAPACITY_TAG_OVRD  2012.5830
# 4          1 2020-06-01 2021-05-31 23:59:59      CAPACITY_TAG_OVRD  2012.5830
# 5          1 2021-06-01 2031-05-31 23:59:59      CAPACITY_TAG_OVRD  2012.5830
# 6          1 2016-01-01 2016-12-31 23:59:59  TRANSMISSION_TAG_OVRD  2634.9495
# 7          1 2017-01-01 2017-12-31 23:59:59  TRANSMISSION_TAG_OVRD  2138.9923
# 8          1 2019-01-01 2019-12-31 23:59:59  TRANSMISSION_TAG_OVRD  2284.3778
# 9          1 2020-01-01 2020-12-31 23:59:59  TRANSMISSION_TAG_OVRD  2284.3778
# 10         1 2021-01-01 2030-12-31 23:59:59  TRANSMISSION_TAG_OVRD  2284.3778
#
#    SourceType           TimeStamp
# 0           H 2019-05-23 09:20:38
# 1           H 2019-05-23 09:20:38
# 2           H 2019-05-23 09:20:38
# 3           H 2019-05-23 09:50:47
# 4           S 2019-05-23 09:50:47
# 5           S 2019-05-23 09:50:47
# 6           H 2019-05-23 09:20:38
# 7           H 2019-05-23 09:20:38
# 8           H 2019-05-23 09:50:47
# 9           S 2019-05-23 09:50:47
# 10          S 2019-05-23 09:50:47

# %% [markdown]
# ### Check Dates

# %% [markdown]
# Ensure tags for all meters cover PR start and end dates.

# %%
ct.checkPRdates(report, pr_rev)
# Out:
# cap tags cover PR start & end dates for all accts in 1-J10Y50_1

# %% [markdown]
# ### Export Report to *write_dir*

# %% [markdown]
# If everything looks good report can be exported to the directory specified above.

# %%
ct.export_report(pr_rev, write_dir)
# Out:
# saved file as CP_1-J10Y50_1.csv

# %% [markdown]
# # 2. Batch Reports

# %% [markdown]
# Batch through PR_rev's and export separate .csv files for each.
#
# **Inputs**
# 1. List of PR_rev's, i.e.
#
# ```python
# ['1-IZEA7Q_1', '1-IZ6GRC_1', ...]
# ```
#
# 2. Directory to write .csv's to
#
# **Output**
# 1. Cap report .csv file for each PR_rev given written to given directory

# %% [markdown]
# ### Give directory and PR_rev list

# %%
write_dir = 'C:\\Users\\wb5888\\Documents\\Cap Tags'

pr_rev_list = ['1-IZEA7Q_1', '1-IZ6GRC_1']

# %% [markdown]
# ### Iterate through above code

# %%
ct.batch_reports(pr_rev_list, write_dir)

# %%
os.chdir('C:\\Users\\wb5888\\Documents\\Python_Code\\CapReport')

accts = np.unique(report.AccountID)
acct = accts[0]
IDRquery = "select  *  from lschannelcutheader@tppe where channel IN  ( '3','1') and recorder like '" + acct + "%'" 
IDRoutput = ct.OracleAPI(IDRquery)

IDRdf = pd.DataFrame.from_records(IDRoutput)
IDRdf.to_csv('IDRdata_query.csv', header = False, index = False)
IDRdf.head()
# Out:
#          0                                   1   2          3   \
# 0  78908119  NEPOOL_WMECO_54024602039_024741000   1 2018-11-01
# 1  78909692  NEPOOL_WMECO_54024602039_024741000   3 2019-01-01
# 2  78909696  NEPOOL_WMECO_54024602039_024741000   3 2020-01-01
# 3  78909699  NEPOOL_WMECO_54024602039_024741000   3 2021-01-01
# 4  78909701  NEPOOL_WMECO_54024602039_024741000   3 2022-01-01
#
#                    4        5     6   7  8   9   ...    30    31  \
# 0 2019-05-20 23:59:59  3912830  3600  01  N  -1  ...  None  None
# 1 2019-12-31 23:59:59  3912894  3600  01  N  -1  ...  None  None
# 2 2020-12-31 23:59:59  3912894  3600  01  N  -1  ...  None  None
# 3 2021-12-31 23:59:59  3912894  3600  01  N  -1  ...  None  None
# 4 2022-12-31 23:59:59  3912894  3600  01  N  -1  ...  None  None
#
#                                     32  33    34              35  \
# 0  NEPOOL_WMECO_54024602039_024741000,   N  None  tesi_interface
# 1   NEPOOL_WMECO_54024602039_024741000   N  None  tesi_interface
# 2   NEPOOL_WMECO_54024602039_024741000   N  None  tesi_interface
# 3   NEPOOL_WMECO_54024602039_024741000   N  None  tesi_interface
# 4   NEPOOL_WMECO_54024602039_024741000   N  None  tesi_interface
#
#                    36   37   38 39
# 0 2019-05-23 14:23:29  0.0  0.0  1
# 1 2019-05-23 14:40:17  0.0  0.0  1
# 2 2019-05-23 14:40:17  0.0  0.0  1
# 3 2019-05-23 14:40:17  0.0  0.0  1
# 4 2019-05-23 14:40:17  0.0  0.0  1
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Cap tags: 6/1/xxxx - 5/31/xxxx+1
# ### Trans tags: 1/1/xxxx - 12/31/xxxx
