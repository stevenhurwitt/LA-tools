# %% [markdown]
# # Forecast/Timeshift

# %% [markdown]
# Set file paths:

# %%
# %matplotlib notebook
import os
import datetime as dt
import pandas as pd
import numpy as pd
import EWX_forecast as ewx

try:
    basepath = "C:\\Users\\wb5888\\LA-tools\\EWX_Forecast"
    os.chdir(basepath)
    
except:
    basepath = '/Users/stevenhurwitt/LA-tools/EWX_Forecast'
    os.chdir(basepath)

json_files = os.path.join(basepath, 'json')
csv_files = os.path.join(basepath, 'csv')

#mypath = "C:\\Users\\wb5888\\Documents\\IDR Data\\NEPOOL\\CLP"
#basepath = mypath

print('working in {}'.format(basepath))
# Out:
# working in /Users/stevenhurwitt/LA-tools/EWX_Forecast

# %% [markdown]
# Browse directory:

# %%
files = ewx.sortdir(csv_files, 10)
# Out:
# files found in dir:  /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv
#                        files                time
# 0  NEPOOL_NRI_2529175006.csv 2019-07-02 21:46:56
# 1  NEPOOL_NRI_6507868006.csv 2019-07-02 21:46:56
# 2  NEPOOL_NRI_4703951002.csv 2019-07-02 21:46:56
# 3                   init.git 2019-07-02 21:46:56
# 4  NEPOOL_NRI_9111788007.csv 2019-07-02 21:46:56

# %% [markdown]
# Choose file to use

# %%
myfile = files.files[0]
print('working with {}.'.format(myfile))
# Out:
# working with NEPOOL_NRI_2529175006.csv.

# %% [markdown]
# ## Run forecasting validations & timeshift
# Inputs are:
# 1. data file (csv or json)
# 2. years to forecast
# 3. read directory
# 4. write directory

# %%
ch3 = ewx.forecast_main(myfile, 10, csv_files, csv_files)
# Out:
# parsing data files...
# using filename NEPOOL_NRI_2529175006.csv.
#                   time     v
# 0  2015-05-01 00:00:00  7.84
# 1  2015-05-01 01:00:00  7.92
# 2  2015-05-01 02:00:00  7.36
# 3  2015-05-01 03:00:00  7.84
# 4  2015-05-01 04:00:00  7.84
# read NEPOOL_NRI_2529175006.csv from /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv.
# running data validations...
# ...
# ...
# ...
# ...
# ...
# usage validated.
# running usage estimation flags...
# writing validated usage file to .csv...
# /Users/stevenhurwitt/LA-tools/EWX_Forecast/EWX_forecast.py:474: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   tmp2.lin[tmp2.lin.isnull()] = tmp2.v[tmp2.lin.isnull()]
# wrote NEPOOL_NRI_2529175006.csv to /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv.
# forecasting...
# forecasted year 0 of 11 with 8736 reads.
# ...

# %%
ch3[ch3.index.year < 2021].plot(y = 'v')
#ch3.plot(y = 'v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
forecast_dates = (dt.datetime.strftime(min(ch3.index), '%m/%d/%y %H:%M:%S'), dt.datetime.strftime(max(ch3.index), '%m/%d/%y %H:%M:%S'))
print('forecast is between: {}'.format(forecast_dates))
# Out:
# forecast is between: ('06/10/15 00:00:00', '05/26/27 23:00:00')
