# %% [markdown]
# # Forecast/Timeshift

# %%
# %matplotlib notebook
import os
import pandas as pd
import EWX_forecast as ewx

#basepath = "/home/jupyter-engiela/LA-tools/EWX_Forecast"
basepath = '/Users/stevenhurwitt/LA-tools/EWX_Forecast'
workaround = os.path.join(basepath, 'forecast_workaround')
json_files = os.path.join(basepath, 'json')
csv_files = os.path.join(basepath, 'csv')

os.chdir(csv_files)

#mypath = "C:\\Users\\wb5888\\Documents\\IDR Data\\NEPOOL\\CLP"
#basepath = mypath

print('working in {}'.format(os.getcwd()))
# Out:
# working in /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv

# %%
files = ewx.sortdir(csv_files, 20)
# Out:
# files found in dir:  /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv
#                                   files                time
# 0   NEPOOL_NRI_4703951002_timeshift.csv 2019-11-17 20:46:08
# 1         NEPOOL_NRI_4703951002_val.csv 2019-11-17 20:46:04
# 2                             .DS_Store 2019-11-17 20:10:33
# 3         NEPOOL_NRI_6507868006_val.csv 2019-11-17 18:22:46
# 4   NEPOOL_NRI_6507868006_timeshift.csv 2019-11-17 18:12:33
# 5             NEPOOL_NRI_4703951002.csv 2019-11-17 16:32:23
# 6             NEPOOL_NRI_6507868006.csv 2019-11-17 16:31:54
# 7   NEPOOL_NRI_2529175006_timeshift.csv 2019-11-17 16:30:11
# 8         NEPOOL_NRI_2529175006_val.csv 2019-11-17 16:30:08
# 9             NEPOOL_NRI_2529175006.csv 2019-09-02 12:59:52
# 10                             init.git 2019-09-02 12:59:52
# 11            NEPOOL_NRI_9111788007.csv 2019-09-02 12:59:52

# %%
myfiles = files.files[[5]]
myfiles
# Out:
# 5    NEPOOL_NRI_4703951002.csv
# Name: files, dtype: object

# %%
df = pd.read_csv(myfiles[5])
df.plot(y = 'v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for f in myfiles:
    ch3 = ewx.forecast_main(f, 10, csv_files, csv_files, False)
# Out:
# parsing data files...
# using filename NEPOOL_NRI_4703951002.csv.
#           time     v
# 0  5/1/15 0:00  2.82
# 1  5/1/15 1:00  2.97
# 2  5/1/15 2:00  1.71
# 3  5/1/15 3:00  2.85
# 4  5/1/15 4:00  2.79
# read NEPOOL_NRI_4703951002.csv from /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv.
# running data validations...
# ...
# ...
# ...
# ...
# ...
# usage validated.
# running usage estimation flags...
# /Users/stevenhurwitt/LA-tools/EWX_Forecast/EWX_forecast.py:590: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp2.lin[tmp2.lin.isnull()] = tmp2.v[tmp2.lin.isnull()]
# writing validated usage file to .csv...
# wrote NEPOOL_NRI_4703951002.csv to /Users/stevenhurwitt/LA-tools/EWX_Forecast/csv.
# forecasting...
# forecasted year 0 of 10 with 19440 reads.
# /Users/stevenhurwitt/LA-tools/EWX_Forecast/EWX_forecast.py:475: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   master = pd.concat([year_data, future], axis = 0)
# /Users/stevenhurwitt/LA-tools/EWX_Forecast/EWX_forecast.py:491: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   master = pd.concat([master, forecast], axis = 0)
# forecasted year 1 of 10 with 26208 reads.
# forecasted year 2 of 10 with 34944 reads.
# forecasted year 3 of 10 with 43680 reads.
# forecasted year 4 of 10 with 52416 reads.

# %%
ch3[ch3.index.year < 2021].plot(y = 'v')
#ch3.plot(y = 'v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for f in files.files[:2]:
    os.chdir(json_files)
    csv = ewx.parse_ewx(f)
    fname = "_".join(f.split('_')[1:])
    writename = fname.replace('.json', '.csv')
    os.chdir(csv_files)
    csv.to_csv(writename)
# Out:
# loading json...
# found 12 reads, creating dataset.
# saving to dataframe...
# loading json...
# found 12 reads, creating dataset.
# saving to dataframe...
