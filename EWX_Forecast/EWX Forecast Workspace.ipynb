# %% [markdown]
# # Forecast/Timeshift

# %%
# %matplotlib notebook
import os
import EWX_forecast as ewx

#basepath = '/Volumes/USB30FD/LA-tools/EWX_Forecast/'
#os.chdir(basepath)
#json_files = os.path.join(basepath, 'json')
#csv_files = os.path.join(basepath, 'csv')

mypath = "C:\\Users\\wb5888\\Documents\\IDR Data\\NEPOOL\\CLP"
basepath = mypath

print('working in {}'.format(basepath))
# Out:
# working in C:\Users\wb5888\Documents\IDR Data\NEPOOL\CLP

# %%
files = ewx.sortdir(basepath, 10)
# Out:
# files found in dir:  C:\Users\wb5888\Documents\IDR Data\NEPOOL\CLP
#                                                files                time
# 0           NEPOOL_CLP_51595546037_885332009_ADJ.csv 2019-06-25 14:57:15
# 1       NEPOOL_CLP_51101743003_597232004_bad_ch3.lse 2019-06-25 10:39:58
# 2  NEPOOL_CLP_51101743003_597232004_ch3_timeshift... 2019-06-25 10:37:19
# 3       NEPOOL_CLP_51101743003_597232004_ch3_val.csv 2019-06-25 10:37:09
# 4           NEPOOL_CLP_51101743003_597232004_ch3.csv 2019-06-25 10:34:20
# 5  NEPOOL_CLP_51220643092_329332003_BAD_CH3_times... 2019-06-24 10:07:05
# 6   NEPOOL_CLP_51220643092_329332003_BAD_CH3_val.csv 2019-06-24 10:06:57
# 7  NEPOOL_CLP_51595546037_885332009_BAD_CH3_times... 2019-06-24 09:53:46
# 8   NEPOOL_CLP_51595546037_885332009_BAD_CH3_val.csv 2019-06-24 09:53:40
# 9       NEPOOL_CLP_51282843036_653432007_BAD_CH3.csv 2019-06-24 09:53:05

# %%
ch3 = ewx.forecast_main(files.files[0], 10, basepath, basepath)
# Out:
# parsing data files...
# using filename NEPOOL_CLP_51595546037_885332009_ADJ.csv.
#    1/1/2019 0:00  9.890092233
# 0  1/1/2019 1:00     9.537783
# 1  1/1/2019 2:00     9.415683
# 2  1/1/2019 3:00     9.264330
# 3  1/1/2019 4:00     9.299943
# 4  1/1/2019 5:00     9.357177
# read NEPOOL_CLP_51595546037_885332009_ADJ.csv from C:\Users\wb5888\Documents\IDR Data\NEPOOL\CLP.
# running data validations...
# ...
# ...
# ...
# ...
# ...
# usage validated.
# running usage estimation flags...
# writing validated usage file to .csv...
# C:\Users\wb5888\LA-tools\EWX_Forecast\EWX_forecast.py:407: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   tmp2.lin[tmp2.lin.isnull()] = tmp2.v[tmp2.lin.isnull()]
# wrote NEPOOL_CLP_51595546037_885332009_ADJ.csv to C:\Users\wb5888\Documents\IDR Data\NEPOOL\CLP.
# forecasting...
# C:\Users\wb5888\LA-tools\EWX_Forecast\EWX_forecast.py:303: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   master = pd.concat([year_data, future], axis = 0)
# forecasted year 0 of 11 with 8736 reads.
# C:\Users\wb5888\LA-tools\EWX_Forecast\EWX_forecast.py:315: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   master = pd.concat([master, forecast], axis = 0)
# forecasted year 1 of 11 with 8736 reads.
# forecasted year 2 of 11 with 8736 reads.
# forecasted year 3 of 11 with 8736 reads.
# forecasted year 4 of 11 with 8736 reads.
# forecasted year 5 of 11 with 8736 reads.
# forecasted year 6 of 11 with 8736 reads.
# forecasted year 7 of 11 with 8736 reads.
# forecasted year 8 of 11 with 8736 reads.
# forecasted year 9 of 11 with 8736 reads.
# forecasted year 10 of 11 with 8736 reads.
# writing forecasts to .csv...
# wrote NEPOOL_CLP_51595546037_885332009_ADJ_timeshift.csv to C:\Users\wb5888\Documents\IDR Data\NEPOOL\CLP.

# %%
#ch3[ch3.index.year < 2021].plot(y = 'v')
ch3.plot(y = 'v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ch3_2.plot(y = 'v', color = 'darkorange')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'a;lsdjfal_timeshift.csv'.split('timeshift')[0]
# Out:
# 'a;lsdjfal_'
