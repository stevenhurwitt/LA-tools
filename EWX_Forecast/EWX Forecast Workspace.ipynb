# %% [markdown]
# # Forecast/Timeshift

# %%
# %matplotlib notebook
import os
import EWX_forecast as ewx

basepath = "C:\\Users\\wb5888\\LA-tools\\EWX_Forecast"
os.chdir(basepath)
json_files = os.path.join(basepath, 'json')
csv_files = os.path.join(basepath, 'csv')

#mypath = "C:\\Users\\wb5888\\Documents\\IDR Data\\NEPOOL\\CLP"
#basepath = mypath

print('working in {}'.format(basepath))
# Out:
# working in C:\Users\wb5888\LA-tools\EWX_Forecast

# %%
files = ewx.sortdir(json_files, 10)
# Out:
# files found in dir:  C:\Users\wb5888\LA-tools\EWX_Forecast\json
#                                                files                time
# 0  20190701073701923000_NEPOOL_PSNH_80010330126.json 2019-07-01 16:02:31
# 1  20190701073703343000_NEPOOL_PSNH_80010330209.json 2019-07-01 16:02:18
# 2   20190610104203499000_NEPOOL_MECO_6276568002.json 2019-06-11 10:06:04
# 3   20190610104100770000_NEPOOL_MECO_0061849009.json 2019-06-11 10:05:20
# 4      engie_NEPOOL_WMECO_54024602039_024741000.json 2019-06-03 07:49:32
# 5      engie_NEPOOL_WMECO_54311202097_965441008.json 2019-06-03 07:49:32
# 6        ewx_NEPOOL_WMECO_54024602039_024741000.json 2019-06-03 07:49:32
# 7        ewx_NEPOOL_WMECO_54311202097_965441008.json 2019-06-03 07:49:32

# %%
ch3 = ewx.forecast_main(files.files[0], 10, basepath, basepath)
# Out:
# parsing data files...
# using filename NEPOOL_PSNH_80010330126.csv.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\LA-tools\EWX_Forecast\EWX_forecast.py in forecast_main(json_file, years, read, write)
#     402             try:
# --> 403                 idr, hb, sca, caps, meter = parse_engie(json_file)
#     404
#
# ~\LA-tools\EWX_Forecast\EWX_forecast.py in parse_engie(payload)
#     102
# --> 103     with open(payload) as raw:
#     104         idr_engie = json.load(raw)
#
# FileNotFoundError: [Errno 2] No such file or directory: '20190701073701923000_NEPOOL_PSNH_80010330126.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ecdb8bea6c24> in <module>
# ----> 1 ch3 = ewx.forecast_main(files.files[0], 10, basepath, basepath)
#
# ~\LA-tools\EWX_Forecast\EWX_forecast.py in forecast_main(json_file, years, read, write)
#     404
#     405             except:
# --> 406                 idr = pd.read_csv(filename)
#     407                 idr.columns = ['t', 'v']
#     408                 idr['v'] = pd.to_numeric(idr['v'])
#
# c:\users\wb5888\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# c:\users\wb5888\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# c:\users\wb5888\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\wb5888\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# c:\users\wb5888\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'NEPOOL_PSNH_80010330126.csv' does not exist: b'NEPOOL_PSNH_80010330126.csv'

# %%
#ch3[ch3.index.year < 2021].plot(y = 'v')
ch3.plot(y = 'v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'a;lsdjfal_timeshift.csv'.split('timeshift')[0]
# Out:
# 'a;lsdjfal_'
